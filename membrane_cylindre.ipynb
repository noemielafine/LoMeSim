# %%
import matplotlib.pyplot as plt

# Lire les données du fichier
z_values = []
p_values = []
with open("pressure_vs_z.dat", "r") as file:
    for line in file:
        z, p = map(float, line.split())
        z_values.append(z)
        p_values.append(p)

# Tracer les données
plt.plot(z_values, p_values, label='Pressure vs Z')
plt.xlabel('Z')
plt.ylabel('Pressure P')
plt.title('Evolution de la pression P dans le cylindre')
plt.legend()
plt.grid(True)
plt.savefig('pressure_vs_z.png')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Lire les données du fichier
data = np.loadtxt("pressure_vs_xz.dat")
x = data[:, 0]
z = data[:, 1]
p = data[:, 2]

# Reshape les données pour correspondre à la grille
nx = len(np.unique(x))
nz = len(np.unique(z))
x = x.reshape((nx, nz))
z = z.reshape((nx, nz))
p = p.reshape((nx, nz))

# Tracer les données sous forme de carte de chaleur
plt.figure()
plt.contourf(x, z, p, levels=50, cmap='viridis')
plt.colorbar(label='Pressure P')
plt.xlabel('X')
plt.ylabel('Z')
plt.title('Evolution de la pression P dans le plan (x, z)')
plt.savefig('pressure_vs_xz.png')
plt.show()

# %%
x_values = []
p_values = []
with open("pressure_vs_x.dat", "r") as file:
    for line in file:
        x, p = map(float, line.split())
        x_values.append(x)
        p_values.append(p)

# Tracer les données
plt.plot(x_values, p_values, label='Pressure vs X')
plt.xlabel('X')
plt.ylabel('Pressure P')
plt.title('Evolution de la pression P dans le cylindre')
plt.legend()
plt.grid(True)
plt.savefig('pressure_vs_x.png')
plt.show()

# %%
import matplotlib.pyplot as plt

o_values = []
po_values = []
with open("pressure_frequence_withmemb_v4.dat", "r") as file:
    for line in file:
        o, po = map(float, line.split())
        o_values.append(o)
        po_values.append(po)

plt.figure(figsize=(10, 6))
plt.plot(o_values, po_values)
# # Charger les données à partir d'un fichier CSV
# df = np.loadtxt('fr12_8_fs.csv')
# # # Accéder aux abscisses (fréquences) et aux ordonnées (impédances)
# frequencies = df[:, 0]
# impedance = df[:, 1]
# plt.plot(frequencies, impedance, label='Données de référence')

# Tracer les données
plt.xscale('log')
plt.xlabel('Fréquence (Hz)')
# plt.xlim([10**1,4*10**3])
plt.ylabel("SPL (dB)")
plt.title("Spectre de la pression RS100-4 Ohm avec membrane 1")
plt.grid(True, which="both", ls="--")
plt.minorticks_on()
plt.tick_params(axis='both', which='both', direction='in', top=True, right=True)
plt.savefig('pressure_frequence_witmemb_v4.png')
# Afficher le graphique
plt.show()

# %%
import matplotlib.pyplot as plt

o_values = []
po_values = []
with open("impedance_frequence_withmemb_v4_ext_a.dat", "r") as file:
    for line in file:
        o, po = map(float, line.split())
        o_values.append(o)
        po_values.append(po)

plt.figure(figsize=(20, 5))
plt.plot(o_values, po_values, color='red')
# # Charger les données à partir d'un fichier CSV
# df = np.loadtxt('fr12_8_fs.csv')
# # # Accéder aux abscisses (fréquences) et aux ordonnées (impédances)
# frequencies = df[:, 0]
# impedance = df[:, 1]
# plt.plot(frequencies, impedance, label='Données de référence')

# Tracer les données
plt.xscale('log')
plt.xlabel('Fréquence (Hz)')
plt.xlim([2*10**1,2*10**4])
plt.ylabel("Impédance (Ohms)")
plt.title("Courbe d'impédance avec membrane 1")
plt.grid(True, which="both", ls="--")
plt.minorticks_on()
plt.tick_params(axis='both', which='both', direction='in', top=True, right=True)
plt.savefig('impedance_frequence_withmemb_v4_ext_a.png')
# Afficher le graphique
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

o_values = []
po_values = []
with open("dphase_frequence_withmemb_v4_ext_a.dat", "r") as file:
    for line in file:
        o, po = map(float, line.split())
        o_values.append(o)
        po_values.append(po)

plt.figure(figsize=(20, 5))
plt.plot(o_values, po_values, color = 'red')
# # Charger les données à partir d'un fichier CSV
# df = np.loadtxt('fr12_8_fs.csv')
# # # Accéder aux abscisses (fréquences) et aux ordonnées (impédances)
# frequencies = df[:, 0]
# impedance = df[:, 1]
# plt.plot(frequencies, impedance, label='Données de référence')

# Tracer les données
plt.xscale('log')
plt.xlabel('Fréquence (Hz)')
plt.xlim([2*10**1,2*10**4])
plt.ylabel("radians")
plt.title("Déphasage entre le haut parleur et la membrane")
plt.grid(True, which="both", ls="--")
plt.minorticks_on()
plt.tick_params(axis='both', which='both', direction='in', top=True, right=True)
plt.savefig('dphase_frequence_withmemb_v4_ext_a.png')
# Afficher le graphique
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Fonction pour charger les données à partir d'un fichier
def load_data(filename):
    data = np.loadtxt(filename)
    frequencies = data[:, 0]
    impedance = data[:, 1]
    return frequencies, impedance

# Liste des fichiers pour les différentes valeurs de h
files = [
    "impedance_frequence_withmemb_v4_V1_M1.dat",
    "impedance_frequence_withmemb_v4_V1_M2.dat",
    "impedance_frequence_withmemb_v4_V1_M3.dat",
    "impedance_frequence_withmemb_v4_V1_M4.dat",
]

# filesm = [
#     "impedance_frequence_CFES_withmemb_GV.dat",
#     "impedance_frequence_CFES_withmemb_V2.dat",
#     "impedance_frequence_CFES_withmemb_V3.dat",
#     "impedance_frequence_CFES_withmemb_V4.dat",
#     "impedance_frequence_CFES_withmemb_V5.dat",
#     "impedance_frequence_CFES_withmemb_V6.dat",
#     "impedance_frequence_CFES_withmemb_MV.dat",
#     "impedance_frequence_CFES_withmemb_PV.dat"
# ]

# Liste des hauteurs correspondantes
volume = [1.738, 1.303, 0.794, 0.511]

# Tracer les courbes d'impédance pour les différentes valeurs de h
plt.figure(figsize=(10, 6))
for i, file in enumerate(files):
    frequencies, impedance = load_data(file)
    plt.plot(frequencies, impedance, label=f"Membrane {i+1}")
# # Charger les données à partir d'un fichier CSV
# df = np.loadtxt('fr12_8_fs.csv')
# # Accéder aux abscisses (fréquences) et aux ordonnées (impédances)
# frequencies = df[:, 0]
# impedance = df[:, 1]
# plt.plot(frequencies, impedance, '+b', label='Données de référence')

# Configurer le graphique
plt.xscale('log')
plt.xlabel('Fréquence (Hz)')
plt.xlim([1,10**3])
plt.ylabel("Impédance (Ohms)")
plt.title("Courbes d'impédance pour différentes membrane (V = 1.738L) - RS100-4")
plt.legend()
plt.grid(True, which="both", ls="--")
plt.minorticks_on()
plt.tick_params(axis='both', which='both', direction='in', top=True, right=True)
plt.savefig('impedance_frequence_withmemb_v4_V1_f(M).png')
# Afficher le graphique
plt.show()

# for i in range(len(volume)) :
#     plt.figure(figsize=(10, 6))
#     frequencies, impedance = load_data(files[i])
#     plt.plot(frequencies, impedance, '+r', label=f"Sans membrane")
#     frequencies, impedance = load_data(filesm[i])
#     plt.plot(frequencies, impedance, label=f"Avec membrane")
#     # Configurer le graphique
#     plt.xscale('log')
#     plt.xlabel('Fréquence (Hz)')
    # plt.xlim([10**1,4*10**3])
#     plt.ylabel("Impédance (Ohms)")
#     plt.title("Courbes d'impédance pour un volume de " + volume[i] + "L")
#     plt.legend()
#     plt.grid(True, which="both", ls="--")
#     plt.minorticks_on()
#     plt.tick_params(axis='both', which='both', direction='in', top=True, right=True)
#     plt.savefig('impedance_frequence_CFES_F12_V'+indice[i]+'.png')
#     # Afficher le graphique
#     plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Fonction pour charger les données à partir d'un fichier
def load_data(filename):
    data = np.loadtxt(filename)
    frequencies = data[:, 0]
    pressure = data[:, 1]
    return frequencies, pressure

# Liste des fichiers pour les différentes valeurs de h
files = [
    "pressure_frequence_withmemb_v4_V1_M1.dat",
    "pressure_frequence_withmemb_v4_V1_M2.dat",
    "pressure_frequence_withmemb_v4_V1_M3.dat",
    "pressure_frequence_withmemb_v4_V1_M4.dat",
]

# filesm = [
#     "pressure_frequence_CFES_withmemb_GV.dat",
#     "pressure_frequence_CFES_withmemb_V2.dat",
#     "pressure_frequence_CFES_withmemb_V3.dat",
#     "pressure_frequence_CFES_withmemb_V4.dat",
#     "pressure_frequence_CFES_withmemb_V5.dat",
#     "pressure_frequence_CFES_withmemb_V6.dat",
#     "pressure_frequence_CFES_withmemb_MV.dat",
#     "pressure_frequence_CFES_withmemb_PV.dat"
# ]

# Liste des hauteurs correspondantes
volume = [1.738, 1.303, 0.794, 0.511]

# Tracer les courbes d'impédance pour les différentes valeurs de h
plt.figure(figsize=(10, 6))
for i, file in enumerate(files):
    frequencies, pressure = load_data(file)
    plt.plot(frequencies, pressure, label=f"Membrane {i+1}")
# # Charger les données à partir d'un fichier CSV
# df = np.loadtxt('fr12_8_fs.csv')
# # Accéder aux abscisses (fréquences) et aux ordonnées (impédances)
# frequencies = df[:, 0]
# pressure = df[:, 1]
# plt.plot(frequencies, pressure, '+b', label='Données de référence')

# Configurer le graphique
plt.xscale('log')
plt.xlabel('Fréquence (Hz)')
plt.xlim([10**1,10**3])
plt.ylabel("SPL (dB)")
plt.title("Spectre de la pression pour différentes membranes (V = 1.738L) - RS100-4")
plt.legend()
plt.grid(True, which="both", ls="--")
plt.minorticks_on()
plt.tick_params(axis='both', which='both', direction='in', top=True, right=True)
plt.savefig('pressure_frequence_withmemb_v4_V1_f(M).png')
# Afficher le graphique
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Charger les données à partir d'un fichier CSV
df = np.loadtxt('fr12_8_fs.csv')

# Accéder aux abscisses (fréquences) et aux ordonnées (impédances)
frequencies = df[:, 0]
impedance = df[:, 1]

# Tracer les données
plt.figure(figsize=(10, 6))
plt.plot(frequencies, impedance, label='Impédance')

# Configurer le graphique
plt.xscale('log')
plt.xlabel('Fréquence (Hz)')
plt.ylabel("Impédance (Ohms)")
plt.title("Courbe d'impédance du FR12-8 ohm")
plt.xlim([20,20*10**3])
plt.legend()
plt.grid(True, which="both", ls="--")
plt.minorticks_on()
plt.tick_params(axis='both', which='both', direction='in', top=True, right=True)
plt.savefig('impedance_FR12_ref.png')
# Afficher le graphique
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

y = np.loadtxt("eigenmodes.dat")
Y = y.T
plt.plot(Y[:, 0:4])
plt.grid()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
import matplotlib.pyplot as plt
import numpy as np

x_values = []
y_values = []
with open("pressureobs_frequence_withmemb_v4_ext_a.dat", "r") as file:
    for line in file:
        x, y = map(float, line.split())
        x_values.append(x)
        y_values.append(y)

plt.figure(figsize=(20, 5))
plt.plot(x_values, y_values, color='orange')

# Tracer les données
plt.xscale('log')
plt.xlabel('Fréquence (Hz)')
plt.xlim([2*10**1,2*10**4])
plt.ylabel("SPL (dB)")
plt.title("Spectre de la pression extérieure RS100-4 Ohm avec membrane 1 (SPL à 1m, 2.83V)")
plt.grid(True, which="both", ls="--")
plt.minorticks_on()
plt.tick_params(axis='both', which='both', direction='in', top=True, right=True)
plt.savefig('pressureobs_frequence_witmemb_v4_ext_1V_a.png')
# Afficher le graphique
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x_values = []
y_values = []
with open("z_frequence_withmemb_v4_ext_a.dat", "r") as file:
    for line in file:
        x, y = map(float, line.split())
        x_values.append(x)
        y_values.append(y)

plt.figure(figsize=(20, 5))
plt.plot(x_values, y_values, color='orange')

# Tracer les données
plt.xscale('log')
plt.xlabel('Fréquence (Hz)')
plt.ylabel("m/V")
plt.xlim([2*10**1,2*10**4])
plt.title("Module de D(0)/U0")
plt.grid(True, which="both", ls="--")
plt.minorticks_on()
plt.tick_params(axis='both', which='both', direction='in', top=True, right=True)
plt.savefig('z_frequence_withmemb_v4_ext_a.png')
# Afficher le graphique
plt.show()
